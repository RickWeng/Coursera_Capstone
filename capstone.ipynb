# %% [markdown]
# # Optimal Chinese Restaurant Location

# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Introduction

# %% [markdown]
# Vancouver has one of the highest concentrations of Chinese people outside the continent of Asia. Chinese account for nearly 28% of the population (Statistics Canada, 2011), which leads to emerging Chinese restaurants over the past decade. The number of Chinese population in Vancouver is likely to continue to grow at a faster rate than the non-Chinese population (Statistics Canada, 2016). An accelerating rise of Chinese restaurants can be expected. Now is a good time for investors to open a Chinese restaurant, the real problem is what is the optimal location?
# Location is important for the success of restaurant because it affects the cost and competition. Locations with high density of population but low density of restaurants in the vicinity are likely to attract more customers. Most restaurant location selection analyses in Vancouver cover rent cost, yet very few address or seriously recognize competition. To address these knowledge gaps, I conduct an assessment of population and restaurant distribution across the City of Vancouver. Local areas are then segmented and clustered accordingly. I assume major customers of Chinese restaurants are Chinese. I pose three questions:
# 1. How is Chinese population distributed in the City of Vancouver?
# 2. How are restaurants distributed in the City of Vancouver?
# 3. Which local area in the City of Vancouver should the investor open a Chinese restaurant?

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Data
# **Local Area Boundary**
# Local Area Boundary (City of Vancouver, 2019) contains the polygons for the city’s 22 local areas (also known as local planning areas). These boundaries generally follow street centrelines. Shape area can be calculated. Centroid as the arithmetic mean position of the polygon were also derived for further analysis.
# **2016 Census of Population**
# The 2016 Census (Statistics Canada, 2016) provides statistical information about the population. Visible minority for the population in private households was used to assess the number of Chinese population in each of the city's 22 Local Areas. Visible minorities refer to persons, other than Aboriginal peoples, who are non-Caucasian in race or non-white in colour. The visible minority population consists many groups such as Chinese, Black, Latin American and Arab. The density of Chinese population in each local area can be then calculated.
# **Foursquare API**
# Foursquare builds a massive dataset of location data. Using Foursquare API and centroid coordinates, I can extract spatial and category information about nearby venues of each local area (Foursquare, 2019). To get the number of restaurants in each local area, I filtered venues by venue categories. The density of restaurants in each local area can then be calculated.
# ### Cluster Analysis
# Density-Based Spatial Clustering of Applications with Noise (DBSCAN) is a popular unsupervised clustering algorithm that is commonly used in machine learning (Ester et al., 1996). DBSCAN groups similar points that are close to each other based on a radius and a minimum number of points. Unlike K-means, DBSCAN can identify clusters of arbitrary shape and find outliers without specifying the number of clusters before the clustering process. DBSCAN was used to segment and cluster local areas in the study.

# %% [markdown]
# ## Results

# %%
import requests
import urllib
from zipfile import ZipFile

# %%
# get vancouver boundary shapefile
url = 'ftp://webftp.vancouver.ca/OpenData/shape/local_area_boundary_shp.zip'
response = urllib.request.urlretrieve(url, 'boundary.zip')
with ZipFile('boundary.zip', 'r') as boundary: 
    # print all the contents of the zip file 
    boundary.printdir() 
    
    # extract all files 
    boundary.extractall() 
    print('All files were extracted.')
# Out:
# File Name                                             Modified             Size
# local_area_boundary.dbf                        2019-02-03 02:19:00         6148
# local_area_boundary.prj                        2019-02-03 02:19:00          413
# local_area_boundary.shp                        2019-02-03 02:19:00        20772
# local_area_boundary.shx                        2019-02-03 02:19:00          276
# All files were extracted.

# %%
#import shapefile
#from json import dumps

# %%
# read the shapefile
#reader = shapefile.Reader('local_area_boundary.shp')

#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.12838171597198, 49.21020783981706]},
#   'bbox': [-123.12838171597198,
#    49.21020783981706,
#    -123.12838171597198,
#    49.21020783981706]},
#  {'id': '10',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.12302448465053, 49.226403809722036]},
#   'bbox': [-123.12302448465053,
#    49.226403809722036,
#    -123.12302448465053,
#    49.226403809722036]},
#  {'id': '11',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.13976026550891, 49.24568035065082]},
#   'bbox': [-123.13976026550891,
#    49.24568035065082,
#    -123.13976026550891,
#    49.24568035065082]},
#  {'id': '12',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.1310486505158, 49.264540513921396]},
#   'bbox': [-123.1310486505158,
#    49.264540513921396,
#    -123.1310486505158,
#    49.264540513921396]},
#  {'id': '13',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.12180104784004, 49.245555693157456]},
#   'bbox': [-123.12180104784004,
#    49.245555693157456,
#    -123.12180104784004,
#    49.245555693157456]},
#  {'id': '14',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.13543740310479, 49.28501116202803]},
#   'bbox': [-123.13543740310479,
#    49.28501116202803,
#    -123.13543740310479,
#    49.28501116202803]},
#  {'id': '15',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.03764720211959, 49.21702062437662]},
#   'bbox': [-123.03764720211959,
#    49.21702062437662,
#    -123.03764720211959,
#    49.21702062437662]},
#  {'id': '16',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.04016670661927, 49.247341725772266]},
#   'bbox': [-123.04016670661927,
#    49.247341725772266,
#    -123.04016670661927,
#    49.247341725772266]},
#  {'id': '17',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.04026999509304, 49.277932902087]},
#   'bbox': [-123.04026999509304,
#    49.277932902087,
#    -123.04026999509304,
#    49.277932902087]},
#  {'id': '18',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.06413496140198, 49.22001104473882]},
#   'bbox': [-123.06413496140198,
#    49.22001104473882,
#    -123.06413496140198,
#    49.22001104473882]},
#  {'id': '19',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.07288517222939, 49.24668568425557]},
#   'bbox': [-123.07288517222939,
#    49.24668568425557,
#    -123.07288517222939,
#    49.24668568425557]},
#  {'id': '20',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.08823526080843, 49.27821889760215]},
#   'bbox': [-123.08823526080843,
#    49.27821889760215,
#    -123.08823526080843,
#    49.27821889760215]},
#  {'id': '21',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.06672835106983, 49.27643859705032]},
#   'bbox': [-123.06672835106983,
#    49.27643859705032,
#    -123.06672835106983,
#    49.27643859705032]}]

# %%
column_names = ['Latitude', 'Longitude'] 

# instantiate the dataframe
cloc = pd.DataFrame(columns=column_names)

# %%
# get latitude and longitude of each centroid
for data in van_data:
    cloc_latlon = data['geometry']['coordinates']
    cloc_lat = cloc_latlon[1]
    cloc_lon = cloc_latlon[0]
    cloc = cloc.append({'Latitude': cloc_lat,'Longitude': cloc_lon}, ignore_index=True)

# %%
cloc.head()
# Out:
#     Latitude   Longitude
# 0  49.218755 -123.092038
# 1  49.263065 -123.098513
# 2  49.244766 -123.103147
# 3  49.280747 -123.116567
# 4  49.267540 -123.163295

# %%
# get shape area
shp['AREA'] = shp.area/10**6

# %%
dict = {'Neighborhood':shp['NAME'], 
                'Latitude':cloc['Latitude'], 
                'Longitude':cloc['Longitude'], 
                'Area':shp['AREA']}

# instantiate the dataframe
neighborhood = pd.DataFrame(dict)

# %%
neighborhood.head()
# Out:
#      Neighborhood   Latitude   Longitude      Area
# 0          Sunset  49.218755 -123.092038  6.575731
# 1  Mount Pleasant  49.263065 -123.098513  3.720549
# 2      Riley Park  49.244766 -123.103147  4.931676
# 3        Downtown  49.280747 -123.116567  4.674227
# 4       Kitsilano  49.267540 -123.163295  6.362855

# %%
url_census = 'ftp://webftp.vancouver.ca/opendata/xls/CensusLocalAreaProfiles2016.csv'

# %%
census = urllib.request.urlretrieve(url, 'CensusLocalAreaProfiles2016.csv')

# %%
census = pd.read_csv('CensusLocalAreaProfiles2016.csv',encoding = "ISO-8859-1") 
# Preview the first 5 lines of the loaded data 
census.head()
# Out:
#   The data shown here is provided by Statistics Canada from the 2016 Census as a custom data order for the City of Vancouver using the City's 22 local planning areas  \
# 0  The data may be reproduced provided they are c...
# 1                                                NaN
# 2   CENSUS DATA FOR CITY OF VANCOUVER LOCAL AREAS...
# 3                                                 ID
# 4                                                  1
#
#                                           Unnamed: 1      Unnamed: 2  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                           Variable  Arbutus-Ridge
# 4   Total - Age groups and average age of the pop...          15,295
#
#   Unnamed: 3          Unnamed: 4 Unnamed: 5           Unnamed: 6  \
# 0        NaN                 NaN        NaN                  NaN
# 1        NaN                 NaN        NaN                  NaN
# 2        NaN                 NaN        NaN                  NaN
# 3  Downtown   Dunbar-Southlands   Fairview   Grandview-Woodland
# 4     62,030              21,425     33,620               29,175
#
#           Unnamed: 7                 Unnamed: 8   Unnamed: 9       ...        \
# 0                NaN                        NaN          NaN       ...
# 1                NaN                        NaN          NaN       ...
# 2                NaN                        NaN          NaN       ...
# 3  Hastings-Sunrise   Kensington-Cedar Cottage   Kerrisdale        ...
# 4             34,575                     49,325       13,975       ...
#
#    Unnamed: 16   Unnamed: 17    Unnamed: 18  Unnamed: 19 Unnamed: 20  \
# 0          NaN           NaN            NaN          NaN         NaN
# 1          NaN           NaN            NaN          NaN         NaN
# 2          NaN           NaN            NaN          NaN         NaN
# 3  Riley Park   Shaughnessy   South Cambie   Strathcona      Sunset
# 4       22,555         8,430          7,970       12,585      36,500
#
#            Unnamed: 21 Unnamed: 22       Unnamed: 23     Unnamed: 24  \
# 0                  NaN         NaN               NaN             NaN
# 1                  NaN         NaN               NaN             NaN
# 2                  NaN         NaN               NaN             NaN
# 3  Victoria-Fraserview   West End   West Point Grey   Vancouver CSD
# 4               31,065      47,200            13,065         631,485
#
#       Unnamed: 25
# 0             NaN
# 1             NaN
# 2             NaN
# 3  Vancouver CMA
# 4       2,463,430
#
# [5 rows x 26 columns]

# %%
# get and clean neighborhood names
census.columns = census.iloc[3, :].str.rstrip()

# %%
# remove useless data
census.drop(['ID'], axis=1, inplace=True)
census.drop(['Vancouver CSD', 'Vancouver CMA'], axis=1, inplace=True)
census.drop(census.index[0:4], axis=0, inplace=True)

# %%
del census.columns.name
census.reset_index(drop=True, inplace=True)

# %%
census.head()
# Out:
#                                             Variable Arbutus-Ridge Downtown  \
# 0   Total - Age groups and average age of the pop...        15,295   62,030
# 1                                      0 to 14 years          2015     4000
# 2                                       0 to 4 years           455     2080
# 3                                       5 to 9 years           685     1105
# 4                                     10 to 14 years           880      810
#
#   Dunbar-Southlands Fairview Grandview-Woodland Hastings-Sunrise  \
# 0            21,425   33,620             29,175           34,575
# 1              3545     2580               3210             4595
# 2               675     1240               1320             1510
# 3              1225      760               1025             1560
# 4              1650      580                865             1525
#
#   Kensington-Cedar Cottage Kerrisdale Killarney       ...       Oakridge  \
# 0                   49,325     13,975    29,325       ...         13,030
# 1                     7060       1880      4185       ...           1565
# 2                     2515        430      1300       ...            490
# 3                     2390        600      1400       ...            480
# 4                     2160        845      1485       ...            590
#
#   Renfrew-Collingwood Riley Park Shaughnessy South Cambie Strathcona  Sunset  \
# 0              51,530     22,555       8,430        7,970     12,585  36,500
# 1                6305       3415        1175         1105       1065    5460
# 2                2065       1175         270          360        360    1695
# 3                2115       1160         405          365        365    1780
# 4                2130       1080         500          375        340    1985
#
#   Victoria-Fraserview West End West Point Grey
# 0              31,065   47,200          13,065
# 1                3790     1945            1900
# 2                1175      965             420
# 3                1210      560             670
# 4                1410      415             810
#
# [5 rows x 23 columns]

# %%
# transpose table
tcensus = census.transpose()
tcensus.columns = tcensus.iloc[0,:].str.lstrip()

# %%
# get chinese population
tcensus = tcensus['Chinese'].iloc[1:,0]

# %%
census_df = tcensus.to_frame().reset_index()
census_df.rename(columns={'index':'Neighborhood'}, inplace=True)

# %%
census_df
# Out:
#                 Neighborhood Chinese
# 0              Arbutus-Ridge    6970
# 1                   Downtown    9490
# 2          Dunbar-Southlands    6525
# 3                   Fairview    3865
# 4         Grandview-Woodland    3885
# 5           Hastings-Sunrise   13120
# 6   Kensington-Cedar Cottage   15560
# 7                 Kerrisdale    6445
# 8                  Killarney   11670
# 9                  Kitsilano    3615
# 10                   Marpole   10585
# 11            Mount Pleasant    3580
# 12                  Oakridge    7505
# 13       Renfrew-Collingwood   21370
# 14                Riley Park    5210
# 15               Shaughnessy    3340
# 16              South Cambie    1995
# 17                Strathcona    2865
# 18                    Sunset    8180
# 19       Victoria-Fraserview   15710
# 20                  West End    2740
# 21           West Point Grey    3100

# %%
# join local area boundary table and census table
cleaned_neighborhood = pd.merge(neighborhood, census_df, on='Neighborhood')

# %%
# correct chinese data type to int
cleaned_neighborhood['Chinese'] = cleaned_neighborhood['Chinese'].astype('int')
# get density of chinese population
cleaned_neighborhood['Density_Chinese'] = cleaned_neighborhood['Chinese']/cleaned_neighborhood['Area']

# %%
cleaned_neighborhood
# Out:
#                 Neighborhood   Latitude   Longitude      Area  Chinese  \
# 0                     Sunset  49.218755 -123.092038  6.575731     8180
# 1             Mount Pleasant  49.263065 -123.098513  3.720549     3580
# 2                 Riley Park  49.244766 -123.103147  4.931676     5210
# 3                   Downtown  49.280747 -123.116567  4.674227     9490
# 4                  Kitsilano  49.267540 -123.163295  6.362855     3615
# 5          Dunbar-Southlands  49.237960 -123.189548  9.079848     6525
# 6                 Kerrisdale  49.223655 -123.159576  6.608907     6445
# 7              Arbutus-Ridge  49.246804 -123.161669  3.700620     6970
# 8            West Point Grey  49.268401 -123.203467  5.300219     3100
# 9                    Marpole  49.210208 -123.128382  6.003074    10585
# 10                  Oakridge  49.226404 -123.123024  4.023603     7505
# 11               Shaughnessy  49.245680 -123.139760  4.480286     3340
# 12                  Fairview  49.264541 -123.131049  3.635361     3865
# 13              South Cambie  49.245556 -123.121801  2.176353     1995
# 14                  West End  49.285011 -123.135437  2.256228     2740
# 15                 Killarney  49.217021 -123.037647  6.933989    11670
# 16       Renfrew-Collingwood  49.247342 -123.040167  8.100377    21370
# 17          Hastings-Sunrise  49.277933 -123.040270  8.332271    13120
# 18       Victoria-Fraserview  49.220011 -123.064135  5.500531    15710
# 19  Kensington-Cedar Cottage  49.246686 -123.072885  7.252499    15560
# 20                Strathcona  49.278219 -123.088235  4.369801     2865
# 21        Grandview-Woodland  49.276439 -123.066728  4.754135     3885
#
#     Density_Chinese
# 0       1243.968169
# 1        962.223642
# 2       1056.435881
# 3       2030.282296
# 4        568.141185
# 5        718.624330
# 6        975.199019
# 7       1883.467974
# 8        584.881449
# 9       1763.263213
# 10      1865.243560
# 11       745.488135
# 12      1063.168279
# 13       916.670950
# 14      1214.416348
# 15      1683.014003
# 16      2638.148844
# 17      1574.600765
# 18      2856.088062
# 19      2145.467366
# 20       655.636295
# 21       817.183377

# %%
from geopy.geocoders import Nominatim
import folium

# %%
# geocoding vancouver
address = 'Vancouver, British Columbia'
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Vancouver are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Vancouver are 49.2608724, -123.1139529.

# %%
# map local area boundary and centroid
van_map = folium.Map([latitude, longitude],
                  zoom_start=12,
                  tiles='cartodbpositron')

folium.Choropleth(geo_data=van_json,
                line_color='#66C2A5',
                line_weight=1,
                fill_color='#f2f2f2').add_to(van_map)

for lat, lng, nei in zip(cleaned_neighborhood['Latitude'], cleaned_neighborhood['Longitude'], cleaned_neighborhood['Neighborhood']):
    label = f'Neighborhood: {nei}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#66C2A5',
        fill=True,
        fill_color='#66C2A5',
        fill_opacity=0.7,
        parse_html=False).add_to(van_map)  

van_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# map distribution of chinese population
pop_map = folium.Map([latitude, longitude],
                  zoom_start=12,
                  tiles='cartodbpositron')

pop_map.choropleth(geo_data=van_json,
                data=cleaned_neighborhood,
                columns=['Neighborhood', 'Density_Chinese'],
                key_on='feature.properties.NAME',
                fill_color='YlOrRd',
                fill_opacity=0.7,
                line_color='grey',
                legend_name='Density of Chinese Population (#/km2)') 

pop_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# foursquare information
CLIENT_ID = 'CMGOG4ZRSMWXCBOJ5L1ERRLDS0KBNCDZB5YIQUBYV0RSFESM' # Foursquare ID
CLIENT_SECRET = 'WSNVRUT4NVSFXME5VVG3XQIIVFKJWLC5PVI5OFWNFCJ1NZ5Z' # Foursquare Secret
VERSION = '20190511' # Foursquare API version
category_id = '4bf58dd8d48988d145941735' # Chinese restaurant Category ID

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CMGOG4ZRSMWXCBOJ5L1ERRLDS0KBNCDZB5YIQUBYV0RSFESM
# CLIENT_SECRET:WSNVRUT4NVSFXME5VVG3XQIIVFKJWLC5PVI5OFWNFCJ1NZ5Z

# %%
# create function to get nearby Chinese restaurants
def getNearbyCR(names, latitudes, longitudes, radius=1500, LIMIT=100):
    
    cr_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET,
            lat, 
            lng,
            VERSION,  
            category_id,
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()['response']['venues']
        
        # return only relevant information for each nearby Chinese restaurant
        cr_list.append([(
            name, 
            lat, 
            lng, 
            cr['name'], 
            cr['id'],
            cr['location']['lat'], 
            cr['location']['lng'],  
            cr['categories'][0]['name']) for cr in results])

    nearby_cr = pd.DataFrame([item for cr_list in cr_list for item in cr_list])
    nearby_cr.columns = ['Neighborhood',                   
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue',
                  'Venue ID',
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_cr)

# %%
# get nearby Chinese restaurants
van_cr = getNearbyCR(names=cleaned_neighborhood['Neighborhood'],
                                   latitudes=cleaned_neighborhood['Latitude'],
                                   longitudes=cleaned_neighborhood['Longitude'])
# Out:
# Sunset
# Mount Pleasant
# Riley Park
# Downtown
# Kitsilano
# Dunbar-Southlands
# Kerrisdale
# Arbutus-Ridge
# West Point Grey
# Marpole
# Oakridge
# Shaughnessy
# Fairview
# South Cambie
# West End
# Killarney
# Renfrew-Collingwood
# Hastings-Sunrise
# Victoria-Fraserview
# Kensington-Cedar Cottage
# Strathcona
# Grandview-Woodland

# %%
van_cr.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Sunset              49.218755             -123.092038
# 1       Sunset              49.218755             -123.092038
# 2       Sunset              49.218755             -123.092038
# 3       Sunset              49.218755             -123.092038
# 4       Sunset              49.218755             -123.092038
#
#                              Venue                  Venue ID  Venue Latitude  \
# 0                    Yu Xiang Yuan  5158fe65e4b06ee01ae984c9       49.224628
# 1                       Shoom 雅菀食府  55039916498ee7519a7e1bf9       49.224861
# 2           Deer Garden Signatures  5075d46ee4b0c63048e3740e       49.227635
# 3  Lian Hong Chinese Food & Bakery  4dc6caa9d4c0ad9c0fa94bd3       49.226530
# 4          Neptune Chinese Kitchen  5b6659bb5a2c91002c139a9a       49.210604
#
#    Venue Longitude        Venue Category
# 0      -123.090869    Chinese Restaurant
# 1      -123.090948  Cantonese Restaurant
# 2      -123.090703    Chinese Restaurant
# 3      -123.090620    Dim Sum Restaurant
# 4      -123.092673  Cantonese Restaurant

# %%
# check if wrong subcategory were included in Chinese restaurant
van_cr['Venue Category'].unique()
# Out:
# array(['Chinese Restaurant', 'Cantonese Restaurant', 'Dim Sum Restaurant',
#        'Noodle House', 'Diner', 'Taiwanese Restaurant',
#        'Asian Restaurant', 'Tea Room', 'Hotpot Restaurant',
#        'Shanghai Restaurant', 'Café', 'Szechuan Restaurant',
#        'Fast Food Restaurant', 'Korean Restaurant',
#        'Peking Duck Restaurant', 'Fujian Restaurant', 'Creperie',
#        'Bubble Tea Shop', 'Bakery', 'Donut Shop', 'Arts & Crafts Store'],
#       dtype=object)

# %%
# check venue name of the wrong subcategory
van_cr.loc[van_cr['Venue Category']=='Arts & Crafts Store', ['Venue','Venue Category']]
# Out:
#               Venue       Venue Category
# 504  Bamboo Village  Arts & Crafts Store

# %%
# delete the wrong venue
van_cr.drop(504, axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-87db3a28df1f> in <module>
#       1 # delete the wrong venue
# ----> 2 van_cr.drop(504, axis=0, inplace=True).reset_index()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: '[504] not found in axis'

# %%
van_cr.reset_index(drop=True)
# Out:
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0
# 12                                  Angel Cake & Cafe
# 13                        Flamingo Chinese Restaurant
# 14                                          Chu Kiang
# 15                               Uncle Ming's Kitchen
# 16                                            A2 Cafe
# 17                            Wo's Chinese Restaurant
# 18                                          Moon Café
# 19                               Koon Lock Restaurant
# 20      Congee Noodle House 粥麵館 (Congee Noodle House)
# 21                            Sunny Spot Cafe 张记凉皮肉夹馍
# 22                      Bo Kong Vegetarian Restaurant
# 23                              Heritage Asian Eatery
# 24                                             Tong's
# 25                                 New Sun Restaurant
# 26                          Szechuan House Restaurant
# 27                                Laura's Coffee Shop
# 28                                           Water 80
# 29                                      Fraser & 18th
# ..                                                ...
# 497                      New Town Bakery & Restaurant
# 498                     Goldstone Bakery & Restaurant
# 499                                   Kam Wai Dim Sum
# 500                                       Giant Panda
# 501                   Garden Villa Seafood Restaurant
# 502            On Lok Restaurant & Won-Tun House 安樂麵家
# 503                        Pelican Seafood Restaurant
# 504                                           Bao Bei
# 505                             Congee Noodle Delight
# 506                                           Sai Woo
# 507                  Floata Seafood Restaurant 富大海鮮酒家
# 508                                      Jade Dynasty
# 509                                 Mitzie Restaurant
# 510                          Kentizen Chinese Cuisine
# 511  New Mitzies Restaurant Western & Chinese Cuisine
# 512                                    Won Ton Noodle
# 513                           Prime Time Chicken Ltd.
# 514                                  Chinatown Palace
# 515                        Pelican Seafood Restaurant
# 516            On Lok Restaurant & Won-Tun House 安樂麵家
# 517                           Louis Garden Restaurant
# 518              Van Dragon Chinese Restaurant 雲龍海鮮酒家
# 519                     East No. 1 Seafood Restaurant
# 520                               Penny Restaurant 錢記
# 521                                    Won Ton Noodle
# 522                                 Cindys Palace 頭啖湯
# 523                          Hopewell Chinese Kitchen
# 524                                 James on Hastings
# 525                                        Pink Pearl
# 526                                              Luda
#
#                      Venue ID  Venue Latitude  Venue Longitude  \
# 0    5158fe65e4b06ee01ae984c9       49.224628      -123.090869
# 1    55039916498ee7519a7e1bf9       49.224861      -123.090948
# 2    5075d46ee4b0c63048e3740e       49.227635      -123.090703
# 3    4dc6caa9d4c0ad9c0fa94bd3       49.226530      -123.090620
# 4    5b6659bb5a2c91002c139a9a       49.210604      -123.092673
# 5    4cb22811db32f04d1500ce4d       49.230055      -123.090826
# 6    56188f36498ef927d657b7bc       49.230207      -123.090850
# 7    4f00db0029c201c6fe489b8f       49.227547      -123.090498
# 8    4e5709ad7d8b7535133aa568       49.227786      -123.090359
# 9    4be773c4c5220f471db9a8ca       49.210635      -123.092571
# 10   4c1d8a4bb4e62d7f9105dd93       49.233047      -123.090483
# 11   4af780a3f964a5209f0922e3       49.227979      -123.090478
# 12   4aba809df964a5209f8120e3       49.230175      -123.090848
# 13   5750f11c498eba016c0b4ebc       49.210693      -123.072683
# 14   4ce7207c9f776ea8ab055622       49.225527      -123.077495
# 15   58a3b76ebbec6606e1dffa59       49.211617      -123.102552
#
# 29     Chinese Restaurant
# ..                    ...
# 497    Chinese Restaurant
# 498    Chinese Restaurant
# 499    Chinese Restaurant
# 500    Chinese Restaurant
# 501    Chinese Restaurant
# 502    Chinese Restaurant
# 503      Asian Restaurant
# 504    Chinese Restaurant
# 505    Chinese Restaurant
# 506    Chinese Restaurant
# 507    Chinese Restaurant
# 508    Dim Sum Restaurant
# 509    Chinese Restaurant
# 510    Chinese Restaurant
# 511    Chinese Restaurant
# 512    Chinese Restaurant
# 513  Fast Food Restaurant
# 514    Chinese Restaurant
# 515      Asian Restaurant
# 516    Chinese Restaurant
# 517    Chinese Restaurant
# 518    Chinese Restaurant
# 519    Dim Sum Restaurant
# 520    Chinese Restaurant
# 521    Chinese Restaurant
# 522      Asian Restaurant
# 523    Chinese Restaurant
# 524    Chinese Restaurant
# 525    Chinese Restaurant
# 526    Chinese Restaurant
#
# [527 rows x 8 columns]

# %% [markdown]
# ### Rating

# %%
# create function to get ratings of Chinese restaurants
def getCRating(cr_ids):
    
    cr_rating=[]
    for venue_id in cr_ids:
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET,
            VERSION)
            
        try:
            # make the GET request
            results = requests.get(url).json()['response']['venue']['rating']
            # return id and rating for each Chinese restaurant
            cr_rating.append([venue_id, results])
        except:
            cr_rating.append([venue_id, 'NaN'])
        
    rating = pd.DataFrame(cr_rating)
    rating.columns = ['Venue ID', 'Venue Rating']
    
    return(rating)

# %%
rating_cr = getCRating(cr_ids=van_cr['Venue ID'])

# %%
rating_cr.head()
# Out:
#                    Venue ID Venue Rating
# 0  5158fe65e4b06ee01ae984c9          6.1
# 1  55039916498ee7519a7e1bf9          7.3
# 2  5075d46ee4b0c63048e3740e          7.9
# 3  4dc6caa9d4c0ad9c0fa94bd3          NaN
# 4  5b6659bb5a2c91002c139a9a          NaN

# %% [markdown]
# ### Map

# %%
cr_map = folium.Map(location=[latitude, longitude], 
                    tiles='cartodbpositron',
                    zoom_start=12) # generate map centred around Vancouver

# add circle markers to represent centroids
cr_map.choropleth(geo_data=van_json,
                line_color='#66C2A5',
                line_weight=1,
                fill_color='#f2f2f2')

for lat, lng, nei in zip(cleaned_neighborhood['Latitude'], cleaned_neighborhood['Longitude'], cleaned_neighborhood['Neighborhood']):
    label = f'Neighborhood: {nei}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#66C2A5',
        fill=True,
        fill_color='#66C2A5',
        fill_opacity=0.7,
        parse_html=False).add_to(cr_map)  

# add Chinese restaurants as circle markers
for lat, lng, label in zip(van_cr['Venue Latitude'],van_cr['Venue Longitude'], van_cr['Venue Category']):
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        color='#FC8D62',
        popup=label,
        fill = True,
        fill_color='#FC8D62',
        fill_opacity=0.5
    ).add_to(cr_map)

# add legend
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 50px; left: 50px; width: 200px; height: 90px; 
                            border:none; z-index:9999; font-size:14px;
                            ">&nbsp; <i class="fa fa-circle fa-1x" style="color: #66C2A5"></i> Neighborhood &nbsp<br>
                              &nbsp; <i class="fa fa-circle fa-1x" style="color: #FC8D62"></i> Chinese Restaurant &nbsp 
                </div>
                ''' 
cr_map.get_root().html.add_child(folium.Element(legend_html))



# display map
cr_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# get heat data for heat map
heat_data = [[row['Venue Latitude'],row['Venue Longitude']] for index, row in van_cr.iterrows()]

# %%
from folium import plugins
from folium.plugins import HeatMap

# %%
# heat map for Chinese restaurants
heat_map = folium.Map([latitude, longitude],
                  zoom_start=12,
                  tiles='CartoDB Dark_Matter')
HeatMap(heat_data,
       radius=25).add_to(heat_map)

heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
van_cr.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Sunset              49.218755             -123.092038
# 1       Sunset              49.218755             -123.092038
# 2       Sunset              49.218755             -123.092038
# 3       Sunset              49.218755             -123.092038
# 4       Sunset              49.218755             -123.092038
#
#                              Venue                  Venue ID  Venue Latitude  \
# 0                    Yu Xiang Yuan  5158fe65e4b06ee01ae984c9       49.224628
# 1                       Shoom 雅菀食府  55039916498ee7519a7e1bf9       49.224861
# 2           Deer Garden Signatures  5075d46ee4b0c63048e3740e       49.227635
# 3  Lian Hong Chinese Food & Bakery  4dc6caa9d4c0ad9c0fa94bd3       49.226530
# 4          Neptune Chinese Kitchen  5b6659bb5a2c91002c139a9a       49.210604
#
#    Venue Longitude        Venue Category
# 0      -123.090869    Chinese Restaurant
# 1      -123.090948  Cantonese Restaurant
# 2      -123.090703    Chinese Restaurant
# 3      -123.090620    Dim Sum Restaurant
# 4      -123.092673  Cantonese Restaurant

# %%
# add rating to original table
van_cr = van_cr.merge(rating_cr, how='outer', on='Venue ID')
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Sunset              49.218755             -123.092038
# 1       Sunset              49.218755             -123.092038
# 2       Sunset              49.218755             -123.092038
# 3       Sunset              49.218755             -123.092038
# 4       Sunset              49.218755             -123.092038
#
#                              Venue                  Venue ID  Venue Latitude  \
# 0                    Yu Xiang Yuan  5158fe65e4b06ee01ae984c9       49.224628
# 1                       Shoom 雅菀食府  55039916498ee7519a7e1bf9       49.224861
# 2           Deer Garden Signatures  5075d46ee4b0c63048e3740e       49.227635
# 3  Lian Hong Chinese Food & Bakery  4dc6caa9d4c0ad9c0fa94bd3       49.226530
# 4          Neptune Chinese Kitchen  5b6659bb5a2c91002c139a9a       49.210604
#
#    Venue Longitude        Venue Category Venue Rating
# 0      -123.090869    Chinese Restaurant          6.1
# 1      -123.090948  Cantonese Restaurant          7.3
# 2      -123.090703    Chinese Restaurant          7.9
# 3      -123.090620    Dim Sum Restaurant          NaN
# 4      -123.092673  Cantonese Restaurant          NaN

# %%
van_cr
# Out:
#                   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0                       Sunset              49.218755             -123.092038
# 1                       Sunset              49.218755             -123.092038
# 2                       Sunset              49.218755             -123.092038
# 3                       Sunset              49.218755             -123.092038
# 4                       Sunset              49.218755             -123.092038
# 5                       Sunset              49.218755             -123.092038
# 6                       Sunset              49.218755             -123.092038
# 7                       Sunset              49.218755             -123.092038
# 8                       Sunset              49.218755             -123.092038
# 9                       Sunset              49.218755             -123.092038
# 10                      Sunset              49.218755             -123.092038
# 11                      Sunset              49.218755             -123.092038
# 12                  Riley Park              49.244766             -123.103147
# 13                  Riley Park              49.244766             -123.103147
# 14                      Sunset              49.218755             -123.092038
# 15                      Sunset              49.218755             -123.092038
# 16                      Sunset              49.218755             -123.092038
4fa41b5de4b0bbcd48ee36db       49.280758      -123.080161
# 1033  4c144094a9c220a13d57579d       49.280993      -123.101167
# 1034  4ce444fcf5f9236a028b8461       49.279271      -123.097966
# 1035  53829c5d498e1f5b42524a89       49.279686      -123.107361
# 1036  4c2a8ba1b34ad13a8178e8ce       49.279420      -123.098798
# 1037  4bdda6fae75c0f47060fc503       49.280430      -123.098424
# 1038  4bf198e378cec9287398ba86       49.280431      -123.101287
# 1039  4ab68343f964a520867720e3       49.281001      -123.063398
# 1040  4ab68343f964a520867720e3       49.281001      -123.063398
# 1041  4ab68343f964a520867720e3       49.281001      -123.063398
# 1042  4ab68343f964a520867720e3       49.281001      -123.063398
# 1043  4ca8e7f2d971b1f7a76d19e1       49.281497      -123.066215
# 1044  4ca8e7f2d971b1f7a76d19e1       49.281497      -123.066215
# 1045  4ca8e7f2d971b1f7a76d19e1       49.281497      -123.066215
# 1046  4ca8e7f2d971b1f7a76d19e1       49.281497      -123.066215
# 1047  4c63416969a1c9b679d33aa4       49.280397      -123.100124
# 1048  520ec5fb11d2f0aec253b8c1       49.282022      -123.104674
# 1049  4d5063b09d4937045527c139       49.280408      -123.100393
# 1050  4baf3285f964a52078f03be3       49.281410      -123.063747
# 1051  4baf3285f964a52078f03be3       49.281410      -123.063747
# 1052  4baf3285f964a52078f03be3       49.281410      -123.063747
# 1053  4baf3285f964a52078f03be3       49.281410      -123.063747
# 1054  4d9ad9ed73df8cfa7733e8ec       49.280317      -123.092330
#
#             Venue Category Venue Rating
# 0       Chinese Restaurant          6.1
# 1     Cantonese Restaurant          7.3
# 2       Chinese Restaurant          7.9
# 3       Dim Sum Restaurant          NaN
# 4     Cantonese Restaurant          NaN
# 5       Chinese Restaurant          6.5
# 6     Cantonese Restaurant          NaN
# 7       Chinese Restaurant          NaN
# 8       Chinese Restaurant          NaN
# 9       Chinese Restaurant          5.7
# 10      Chinese Restaurant          7.3
# 11      Chinese Restaurant          7.3
# 12      Chinese Restaurant          7.3
# 13      Chinese Restaurant          7.3
# 14      Chinese Restaurant          7.4
# 15      Chinese Restaurant          5.7
# 16      Chinese Restaurant          NaN
# 17      Chinese Restaurant          NaN
# 18      Chinese Restaurant          NaN
# 19      Chinese Restaurant          NaN
# 20      Chinese Restaurant          NaN
# 21      Chinese Restaurant          NaN
# 22      Chinese Restaurant          NaN
# 23      Chinese Restaurant          NaN
# 24    Cantonese Restaurant          NaN
# 25    Cantonese Restaurant          NaN
# 26    Cantonese Restaurant          NaN
# 27    Cantonese Restaurant          NaN
# 28      Chinese Restaurant          NaN
# 29      Chinese Restaurant          NaN
# ...                    ...          ...
# 1025    Chinese Restaurant          NaN
# 1026    Chinese Restaurant          NaN
# 1027  Cantonese Restaurant          NaN
# 1028    Chinese Restaurant          NaN
# 1029    Chinese Restaurant          NaN
# 1030    Chinese Restaurant          NaN
# 1031    Chinese Restaurant          NaN
# 1032    Chinese Restaurant          NaN
# 1033    Chinese Restaurant          NaN
# 1034    Chinese Restaurant          NaN
# 1035   Szechuan Restaurant          NaN
# 1036    Chinese Restaurant          NaN
# 1037    Chinese Restaurant          NaN
# 1038    Chinese Restaurant          NaN
# 1039    Chinese Restaurant          NaN
# 1040    Chinese Restaurant          NaN
# 1041    Chinese Restaurant          NaN
# 1042    Chinese Restaurant          NaN
# 1043      Asian Restaurant          NaN
# 1044      Asian Restaurant          NaN
# 1045      Asian Restaurant          NaN
# 1046      Asian Restaurant          NaN
# 1047    Chinese Restaurant          NaN
# 1048    Chinese Restaurant          NaN
# 1049    Chinese Restaurant          NaN
# 1050    Chinese Restaurant          NaN
# 1051    Chinese Restaurant          NaN
# 1052    Chinese Restaurant          NaN
# 1053    Chinese Restaurant          NaN
# 1054    Chinese Restaurant          NaN
#
# [1055 rows x 9 columns]

# %%
van_cr.loc[van_cr['Venue Rating']=='NaN'].reset_index()
# Out:
#      index              Neighborhood  Neighborhood Latitude  \
# 0        3                    Sunset              49.218755
# 1        4                    Sunset              49.218755
# 2        6                    Sunset              49.218755
# 3        7                    Sunset              49.218755
# 4        8                    Sunset              49.218755
# 5       16                    Sunset              49.218755
# 6       17                    Sunset              49.218755
# 7       18       Victoria-Fraserview              49.220011
# 8       19       Victoria-Fraserview              49.220011
# 9       20                    Sunset              49.218755
# 10      21                    Sunset              49.218755
# 11      22       Victoria-Fraserview              49.220011
# 12      23       Victoria-Fraserview              49.220011
# 13      24                    Sunset              49.218755
# 14      25                    Sunset              49.218755
# 15      26                   Marpole              49.210208
# 16      27                   Marpole              49.210208
# 17      28                    Sunset              49.218755
# 18      29                    Sunset              49.218755
# 19      30                Riley Park              49.244766
# 20      31                Riley Park              49.244766
# 21      32                    Sunset              49.218755
# 22      33                    Sunset              49.218755
# 23      34                   Marpole              49.210208
# 24      35                   Marpole              49.210208
# 25      36                    Sunset              49.218755
# 26      37                    Sunset              49.218755
# 27      40            Mount Pleasant              49.263065
# 28      41            Mount Pleasant              49.263065
# 29      42                Riley Park              49.244766
# ..     ...                       ...                    ...
# 673   1025  Kensington-Cedar Cottage              49.246686
# 674   1026  Kensington-Cedar Cottage              49.246686
# 675   1027  Kensington-Cedar Cottage              49.246686
# 676   1028  Kensington-Cedar Cottage              49.246686
# 677   1029                Strathcona              49.278219
# 678   1030                Strathcona              49.278219
# 679   1031        Grandview-Woodland              49.276439
# 680   1032        Grandview-Woodland              49.276439
# 681   1033                Strathcona              49.278219
# 682   1034                Strathcona              49.278219
# 683   1035                Strathcona              49.278219
# 684   1036                Strathcona              49.278219
# 685   1037                Strathcona              49.278219
# 686   1038                Strathcona              49.278219
# 687   1039                Strathcona              49.278219
# 688   1040                Strathcona              49.278219
# 689   1041        Grandview-Woodland              49.276439
# 690   1042        Grandview-Woodland              49.276439
# 691   1043                Strathcona              49.278219
# 692   1044                Strathcona              49.278219
# 693   1045        Grandview-Woodland              49.276439
# 694   1046        Grandview-Woodland              49.276439
# 695   1047                Strathcona              49.278219
# 696   1048                Strathcona              49.278219
# 697   1049                Strathcona              49.278219
# 698   1050                Strathcona              49.278219
# 699   1051                Strathcona              49.278219
# 700   1052        Grandview-Woodland              49.276439
# 701   1053        Grandview-Woodland              49.276439
# 702   1054                Strathcona              49.278219
#
#      Neighborhood Longitude                                             Venue  \
# 0               -123.092038                   Lian Hong Chinese Food & Bakery
# 1               -123.092038                           Neptune Chinese Kitchen
# 2               -123.092038                                   Angel Cafe 君怡餐廳
# 3               -123.092038                       Sun Yard Chinese Restaurant
# 4               -123.092038                                                冠樂
# 5               -123.092038                       Flamingo Chinese Restaurant
# 6               -123.092038                       Flamingo Chinese Restaurant
# 7               -123.064135                       Flamingo Chinese Restaurant
# 8               -123.064135                       Flamingo Chinese Restaurant
# 9               -123.092038                                         Chu Kiang
# 10              -123.092038                                         Chu Kiang
# 11              -123.064135                                         Chu Kiang
# 12              -123.064135                                         Chu Kiang
# 13              -123.092038                              Uncle Ming's Kitchen
# 14              -123.092038                              Uncle Ming's Kitchen
# 15              -123.128382                              Uncle Ming's Kitchen
# 16              -123.128382                              Uncle Ming's Kitchen
# 17              -123.092038                                           A2 Cafe
# 18              -123.092038                                           A2 Cafe
# 19              -123.103147                                           A2 Cafe
# 20              -123.103147                                           A2 Cafe
# 21              -123.092038                           Wo's Chinese Restaurant
# 22              -123.092038                           Wo's Chinese Restaurant
# 23              -123.128382                           Wo's Chinese Restaurant
# 24              -123.128382                           Wo's Chinese Restaurant
# 25              -123.092038                                         Moon Café
# 26              -123.092038                              Koon Lock Restaurant
# 27              -123.098513                     Bo Kong Vegetarian Restaurant
# 28              -123.098513                     Bo Kong Vegetarian Restaurant
# 29              -123.103147                     Bo Kong Vegetarian Restaurant
# ..                      ...                                               ...
# 673             -123.072885                           Buddha's Orient Express
# 674             -123.072885                                             松林居餐廳
# 675             -123.072885                                  Sun Tin Day Cafe
# 676             -123.072885                  Happy Blossom Seafood Restaurant
# 677             -123.088235                                        Pink Pearl
# 678             -123.088235                                        Pink Pearl
# 679             -123.066728                                        Pink Pearl
# 680             -123.066728                                        Pink Pearl
# 681             -123.088235                    Grand Villa Chinese Restaurant
# 682             -123.088235                                      Kam's Garden
# 683             -123.088235            The Original Szechuan Chongqing Bistro
# 684             -123.088235                                    Kent's Kitchen
# 685             -123.088235                                   Kam Wai Dim Sum
# 686             -123.088235                   Garden Villa Seafood Restaurant
# 687             -123.088235            On Lok Restaurant & Won-Tun House 安樂麵家
# 688             -123.088235            On Lok Restaurant & Won-Tun House 安樂麵家
# 689             -123.066728            On Lok Restaurant & Won-Tun House 安樂麵家
# 690             -123.066728            On Lok Restaurant & Won-Tun House 安樂麵家
# 691             -123.088235                        Pelican Seafood Restaurant
# 692             -123.088235                        Pelican Seafood Restaurant
# 693             -123.066728                        Pelican Seafood Restaurant
# 694             -123.066728                        Pelican Seafood Restaurant
# 695             -123.088235                                 Mitzie Restaurant
# 696             -123.088235                          Kentizen Chinese Cuisine
# 697             -123.088235  New Mitzies Restaurant Western & Chinese Cuisine
# 698             -123.088235                                    Won Ton Noodle
# 699             -123.088235                                    Won Ton Noodle
# 700             -123.066728                                    Won Ton Noodle
# 701             -123.066728                                    Won Ton Noodle
# 702             -123.088235                                  Chinatown Palace
#
#                      Venue ID  Venue Latitude  Venue Longitude  \
# 0    4dc6caa9d4c0ad9c0fa94bd3       49.226530      -123.090620
# 1    5b6659bb5a2c91002c139a9a       49.210604      -123.092673
# 2    56188f36498ef927d657b7bc       49.230207      -123.090850
# 3    4f00db0029c201c6fe489b8f       49.227547      -123.090498
# 4    4e5709ad7d8b7535133aa568       49.227786      -123.090359
# 5    5750f11c498eba016c0b4ebc       49.210693      -123.072683
# 6    5750f11c498eba016c0b4ebc       49.210693      -123.072683
# 7    5750f11c498eba016c0b4ebc       49.210693      -123.072683
# 8    5750f11c498eba016c0b4ebc       49.210693      -123.072683
# 9    4ce7207c9f776ea8ab055622       49.225527      -123.077495
#
# 12     Chinese Restaurant          NaN
# 13   Cantonese Restaurant          NaN
# 14   Cantonese Restaurant          NaN
# 15   Cantonese Restaurant          NaN
# 16   Cantonese Restaurant          NaN
# 17     Chinese Restaurant          NaN
# 18     Chinese Restaurant          NaN
# 19     Chinese Restaurant          NaN
# 20     Chinese Restaurant          NaN
# 21     Chinese Restaurant          NaN
# 22     Chinese Restaurant          NaN
# 23     Chinese Restaurant          NaN
# 24     Chinese Restaurant          NaN
# 25     Chinese Restaurant          NaN
# 26     Chinese Restaurant          NaN
# 27     Chinese Restaurant          NaN
# 28     Chinese Restaurant          NaN
# 29     Chinese Restaurant          NaN
# ..                    ...          ...
# 673    Chinese Restaurant          NaN
# 674    Chinese Restaurant          NaN
# 675  Cantonese Restaurant          NaN
# 676    Chinese Restaurant          NaN
# 677    Chinese Restaurant          NaN
# 678    Chinese Restaurant          NaN
# 679    Chinese Restaurant          NaN
# 680    Chinese Restaurant          NaN
# 681    Chinese Restaurant          NaN
# 682    Chinese Restaurant          NaN
# 683   Szechuan Restaurant          NaN
# 684    Chinese Restaurant          NaN
# 685    Chinese Restaurant          NaN
# 686    Chinese Restaurant          NaN
# 687    Chinese Restaurant          NaN
# 688    Chinese Restaurant          NaN
# 689    Chinese Restaurant          NaN
# 690    Chinese Restaurant          NaN
# 691      Asian Restaurant          NaN
# 692      Asian Restaurant          NaN
# 693      Asian Restaurant          NaN
# 694      Asian Restaurant          NaN
# 695    Chinese Restaurant          NaN
# 696    Chinese Restaurant          NaN
# 697    Chinese Restaurant          NaN
# 698    Chinese Restaurant          NaN
# 699    Chinese Restaurant          NaN
# 700    Chinese Restaurant          NaN
# 701    Chinese Restaurant          NaN
# 702    Chinese Restaurant          NaN
#
# [703 rows x 10 columns]

# %%
# change data to float
van_cr['Venue Rating'] = van_cr['Venue Rating'].astype('float')

# %%
med_rating = van_cr[['Neighborhood','Venue Rating']].groupby('Neighborhood').median()
med_rating = med_rating.reset_index()
med_rating.head()
# Out:
#          Neighborhood  Venue Rating
# 0       Arbutus-Ridge          6.45
# 1            Downtown          6.30
# 2   Dunbar-Southlands           NaN
# 3            Fairview          6.20
# 4  Grandview-Woodland          6.10

# %%
ordered_mrating = med_rating.sort_values(by='Venue Rating', ascending=False)
ordered_mrating.reset_index(drop=True)
ordered_mrating.head()
# Out:
#            Neighborhood  Venue Rating
# 19  Victoria-Fraserview          7.80
# 17           Strathcona          7.45
# 18               Sunset          7.30
# 11       Mount Pleasant          6.65
# 13  Renfrew-Collingwood          6.50

# %%
plt.figure(figsize=(8,6), dpi=300)
# grouped boxplot
sns.boxplot(x='Venue Rating', y='Neighborhood', data=van_cr, palette="viridis", order=ordered_mrating['Neighborhood'])

# %%
# order neighborhood by number of ratings 
num_rating = van_cr[['Neighborhood','Venue Rating']].groupby('Neighborhood').count()
num_rating = num_rating.reset_index()
ordered_nr = num_rating.sort_values(by='Venue Rating', ascending=False)
ordered_nr['Neighborhood']
# Out:
# 1                     Downtown
# 3                     Fairview
# 20                    West End
# 11              Mount Pleasant
# 14                  Riley Park
# 16                South Cambie
# 13         Renfrew-Collingwood
# 17                  Strathcona
# 6     Kensington-Cedar Cottage
# 18                      Sunset
# 0                Arbutus-Ridge
# 9                    Kitsilano
# 7                   Kerrisdale
# 12                    Oakridge
# 15                 Shaughnessy
# 10                     Marpole
# 5             Hastings-Sunrise
# 4           Grandview-Woodland
# 19         Victoria-Fraserview
# 8                    Killarney
# 2            Dunbar-Southlands
# Name: Neighborhood, dtype: object

# %%
# histogram of rating
h = sns.FacetGrid(van_cr, col='Neighborhood',col_wrap=3, xlim=(4,10), ylim=(0,15),col_order=ordered_nr['Neighborhood'])
h = h.set(xticks=np.arange(4,11,1))
h = h.map(plt.hist, 'Venue Rating', color='#E41A1C',bins=np.arange(4, 11,0.5))
h = h.set_titles('{col_name}')

# %%
np.arange(4, 10, 1)
# Out:
# array([4, 5, 6, 7, 8, 9])

# %%
import math

# %%
cleaned_neighborhood
# Out:
#                 Neighborhood   Latitude   Longitude      Area  Chinese  \
# 0                     Sunset  49.218755 -123.092038  6.575731     8180
# 1             Mount Pleasant  49.263065 -123.098513  3.720549     3580
# 2                 Riley Park  49.244766 -123.103147  4.931676     5210
# 3                   Downtown  49.280747 -123.116567  4.674227     9490
# 4                  Kitsilano  49.267540 -123.163295  6.362855     3615
# 5          Dunbar-Southlands  49.237960 -123.189548  9.079848     6525
# 6                 Kerrisdale  49.223655 -123.159576  6.608907     6445
# 7              Arbutus-Ridge  49.246804 -123.161669  3.700620     6970
# 8            West Point Grey  49.268401 -123.203467  5.300219     3100
# 9                    Marpole  49.210208 -123.128382  6.003074    10585
# 10                  Oakridge  49.226404 -123.123024  4.023603     7505
# 11               Shaughnessy  49.245680 -123.139760  4.480286     3340
# 12                  Fairview  49.264541 -123.131049  3.635361     3865
# 13              South Cambie  49.245556 -123.121801  2.176353     1995
# 14                  West End  49.285011 -123.135437  2.256228     2740
# 15                 Killarney  49.217021 -123.037647  6.933989    11670
# 16       Renfrew-Collingwood  49.247342 -123.040167  8.100377    21370
# 17          Hastings-Sunrise  49.277933 -123.040270  8.332271    13120
# 18       Victoria-Fraserview  49.220011 -123.064135  5.500531    15710
# 19  Kensington-Cedar Cottage  49.246686 -123.072885  7.252499    15560
# 20                Strathcona  49.278219 -123.088235  4.369801     2865
# 21        Grandview-Woodland  49.276439 -123.066728  4.754135     3885
#
#     Density_Chinese
# 0       1243.968169
# 1        962.223642
# 2       1056.435881
# 3       2030.282296
# 4        568.141185
# 5        718.624330
# 6        975.199019
# 7       1883.467974
# 8        584.881449
# 9       1763.263213
# 10      1865.243560
# 11       745.488135
# 12      1063.168279
# 13       916.670950
# 14      1214.416348
# 15      1683.014003
# 16      2638.148844
# 17      1574.600765
# 18      2856.088062
# 19      2145.467366
# 20       655.636295
# 21       817.183377

# %%
# get density of Chinese restaurants
density_cr = van_cr.groupby('Neighborhood').count()/(math.pi*1500**2/10**6)
density_cr = density_cr[['Venue']].reset_index()
density_cr.rename(columns={'Venue':'Density_CR'}, inplace=True)
summary = cleaned_neighborhood.merge(density_cr, how='outer', on='Neighborhood')
summary.fillna(0,inplace=True)

# %%
summary = summary.merge(med_rating, how='outer', on='Neighborhood')
summary
# Out:
#                 Neighborhood   Latitude   Longitude      Area  Chinese  \
# 0                     Sunset  49.218755 -123.092038  6.575731     8180
# 1             Mount Pleasant  49.263065 -123.098513  3.720549     3580
# 2                 Riley Park  49.244766 -123.103147  4.931676     5210
# 3                   Downtown  49.280747 -123.116567  4.674227     9490
# 4                  Kitsilano  49.267540 -123.163295  6.362855     3615
# 5          Dunbar-Southlands  49.237960 -123.189548  9.079848     6525
# 6                 Kerrisdale  49.223655 -123.159576  6.608907     6445
# 7              Arbutus-Ridge  49.246804 -123.161669  3.700620     6970
# 8            West Point Grey  49.268401 -123.203467  5.300219     3100
# 9                    Marpole  49.210208 -123.128382  6.003074    10585
# 10                  Oakridge  49.226404 -123.123024  4.023603     7505
# 11               Shaughnessy  49.245680 -123.139760  4.480286     3340
# 12                  Fairview  49.264541 -123.131049  3.635361     3865
# 13              South Cambie  49.245556 -123.121801  2.176353     1995
# 14                  West End  49.285011 -123.135437  2.256228     2740
# 15                 Killarney  49.217021 -123.037647  6.933989    11670
# 16       Renfrew-Collingwood  49.247342 -123.040167  8.100377    21370
# 17          Hastings-Sunrise  49.277933 -123.040270  8.332271    13120
# 18       Victoria-Fraserview  49.220011 -123.064135  5.500531    15710
# 19  Kensington-Cedar Cottage  49.246686 -123.072885  7.252499    15560
# 20                Strathcona  49.278219 -123.088235  4.369801     2865
# 21        Grandview-Woodland  49.276439 -123.066728  4.754135     3885
#
#     Density_Chinese  Density_CR  Venue Rating
# 0       1243.968169    3.678248          7.30
# 1        962.223642   13.439751          6.65
# 2       1056.435881   12.732395          6.50
# 3       2030.282296   15.703288          6.30
# 4        568.141185    5.092958          6.20
# 5        718.624330    0.707355           NaN
# 6        975.199019    3.961190          6.45
# 7       1883.467974    5.234429          6.45
# 8        584.881449    0.000000           NaN
# 9       1763.263213    3.112363          6.40
# 10      1865.243560    3.253834          6.40
# 11       745.488135    5.800313          6.20
# 12      1063.168279   16.976527          6.20
# 13       916.670950   11.600627          6.35
# 14      1214.416348   12.873867          6.20
# 15      1683.014003    1.273240          5.80
# 16      2638.148844    7.497966          6.50
# 17      1574.600765    2.829421          6.10
# 18      2856.088062    3.112363          7.80
# 19      2145.467366   10.610330          6.50
# 20       655.636295    6.366198          7.45
# 21       817.183377    3.395305          6.10

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
# plot density of Chinese population
plt.figure(figsize=(8,6),dpi=300)

# reorder density of Chinese population
ordered_summary = summary.sort_values(by='Density_Chinese')
my_range=range(1,len(summary.index)+1)
# lollipop
plt.hlines(y=my_range, xmin=0, xmax=ordered_summary['Density_Chinese'], color='grey')
plt.plot(ordered_summary['Density_Chinese'], my_range, 'o', color="#1B9E77", markersize=8)
plt.grid(None,axis='y')
plt.rcParams['grid.color']='#f1f1f1'

# Add titles and axis names
plt.yticks(my_range, ordered_summary['Neighborhood'])
plt.xlabel('Density of Chinese Population (#/km2)')

plt.show()

# %%
# plot density of Chinese population
plt.figure(figsize=(8,6),dpi=300)

# reorder density of Chinese population
ordered_summary = summary.sort_values(by='Density_CR')
my_range=range(1,len(summary.index)+1)
plt.hlines(y=my_range, xmin=0, xmax=ordered_summary['Density_CR'], color='grey')
plt.plot(ordered_summary['Density_CR'], my_range, 'o', color='#D95F02', markersize=8)
plt.grid(None,axis='y')

# Add titles and axis names
plt.yticks(my_range, ordered_summary['Neighborhood'])
plt.xlabel('Density of Chinese Restaurants (#/km2)')

plt.show()

# %% [markdown]
# ### Cluster Analysis

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import DBSCAN

# %%
summary[['Density_Chinese','Density_CR']]
# Out:
#     Density_Chinese  Density_CR
# 0       1243.968169    2.829421
# 1        962.223642    5.375900
# 2       1056.435881    4.810016
# 3       2030.282296    7.073553
# 4        568.141185    2.546479
# 5        718.624330    0.424413
# 6        975.199019    1.980595
# 7       1883.467974    2.405008
# 8        584.881449    0.000000
# 9       1763.263213    2.829421
# 10      1865.243560    1.273240
# 11       745.488135    1.980595
# 12      1063.168279    6.932082
# 13       916.670950    4.102661
# 14      1214.416348    6.932082
# 15      1683.014003    1.273240
# 16      2638.148844    6.083256
# 17      1574.600765    1.697653
# 18      2856.088062    2.263537
# 19      2145.467366    6.224727
# 20       655.636295    3.819719
# 21       817.183377    1.697653

# %%
data = summary[['Density_Chinese', 'Density_CR']]
scaler = MinMaxScaler()
scaler.fit(data)
normalized_data = scaler.transform(data)
normalized_data
# Out:
# array([[0.29538578, 0.4       ],
#        [0.17224284, 0.76      ],
#        [0.21342047, 0.68      ],
#        [0.63906253, 1.        ],
#        [0.        , 0.36      ],
#        [0.06577213, 0.06      ],
#        [0.17791402, 0.28      ],
#        [0.57489394, 0.34      ],
#        [0.00731672, 0.        ],
#        [0.52235567, 0.4       ],
#        [0.56692854, 0.18      ],
#        [0.07751358, 0.28      ],
#        [0.21636302, 0.98      ],
#        [0.15233298, 0.58      ],
#        [0.28246948, 0.98      ],
#        [0.4872809 , 0.18      ],
#        [0.90474463, 0.86      ],
#        [0.43989639, 0.24      ],
#        [1.        , 0.32      ],
#        [0.68940682, 0.88      ],
#        [0.03824176, 0.54      ],
#        [0.10884964, 0.24      ]])

# %%
dbscan = DBSCAN(eps=0.20, min_samples = 2)
clusters = dbscan.fit_predict(normalized_data)

plt.figure(figsize=(8,6),dpi=300)
# plot the cluster assignments
plt.scatter(normalized_data[:, 0], normalized_data[:, 1], c=clusters, cmap="plasma")
plt.xlabel("Normalized Density of Chinese Population")
plt.ylabel("Normalized Density of Chinese Restaurants")

plt.show()

# %%
clusters
# Out:
# array([ 0,  0,  0,  1,  0,  0,  0,  2,  0,  2,  2,  0,  3,  0,  3,  2, -1,
#         2, -1,  1,  0,  0])

# %%
summary['Cluster']=clusters

# %%
summary
# Out:
#                 Neighborhood   Latitude   Longitude      Area  Chinese  \
# 0                     Sunset  49.218755 -123.092038  6.575731     8180
# 1             Mount Pleasant  49.263065 -123.098513  3.720549     3580
# 2                 Riley Park  49.244766 -123.103147  4.931676     5210
# 3                   Downtown  49.280747 -123.116567  4.674227     9490
# 4                  Kitsilano  49.267540 -123.163295  6.362855     3615
# 5          Dunbar-Southlands  49.237960 -123.189548  9.079848     6525
# 6                 Kerrisdale  49.223655 -123.159576  6.608907     6445
# 7              Arbutus-Ridge  49.246804 -123.161669  3.700620     6970
# 8            West Point Grey  49.268401 -123.203467  5.300219     3100
# 9                    Marpole  49.210208 -123.128382  6.003074    10585
# 10                  Oakridge  49.226404 -123.123024  4.023603     7505
# 11               Shaughnessy  49.245680 -123.139760  4.480286     3340
# 12                  Fairview  49.264541 -123.131049  3.635361     3865
# 13              South Cambie  49.245556 -123.121801  2.176353     1995
# 14                  West End  49.285011 -123.135437  2.256228     2740
# 15                 Killarney  49.217021 -123.037647  6.933989    11670
# 16       Renfrew-Collingwood  49.247342 -123.040167  8.100377    21370
# 17          Hastings-Sunrise  49.277933 -123.040270  8.332271    13120
# 18       Victoria-Fraserview  49.220011 -123.064135  5.500531    15710
# 19  Kensington-Cedar Cottage  49.246686 -123.072885  7.252499    15560
# 20                Strathcona  49.278219 -123.088235  4.369801     2865
# 21        Grandview-Woodland  49.276439 -123.066728  4.754135     3885
#
#     Density_Chinese  Density_CR  Venue Rating  Cluster
# 0       1243.968169    3.678248          7.30        0
# 1        962.223642   13.439751          6.65        0
# 2       1056.435881   12.732395          6.50        0
# 3       2030.282296   15.703288          6.30        1
# 4        568.141185    5.092958          6.20        0
# 5        718.624330    0.707355           NaN        0
# 6        975.199019    3.961190          6.45        0
# 7       1883.467974    5.234429          6.45        2
# 8        584.881449    0.000000           NaN        0
# 9       1763.263213    3.112363          6.40        2
# 10      1865.243560    3.253834          6.40        2
# 11       745.488135    5.800313          6.20        0
# 12      1063.168279   16.976527          6.20        3
# 13       916.670950   11.600627          6.35        0
# 14      1214.416348   12.873867          6.20        3
# 15      1683.014003    1.273240          5.80        2
# 16      2638.148844    7.497966          6.50       -1
# 17      1574.600765    2.829421          6.10        2
# 18      2856.088062    3.112363          7.80       -1
# 19      2145.467366   10.610330          6.50        1
# 20       655.636295    6.366198          7.45        0
# 21       817.183377    3.395305          6.10        0

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import bokeh.palettes as bp

# %%
bp.small_palettes['Plasma'][5]
# Out:
# ['#0C0786', '#7C02A7', '#CA4678', '#F79341', '#EFF821']

# %%
cluster_map = folium.Map(location=[latitude, longitude], 
                    tiles='cartodbpositron',
                    zoom_start=12) # generate map centred around the Conrad Hotel

folium.Choropleth(geo_data=van_json,
                line_color='black',
                line_weight=1,
                fill_opacity=0,
                fill_color='#f2f2f2').add_to(cluster_map)

# set color scheme for the clusters
colors = ['#0C0786', '#7C02A7', '#CA4678', '#F79341', '#EFF821']

markers_colors = []
for lat, lng, name, clu in zip(summary['Latitude'], summary['Longitude'], summary['Neighborhood'], summary['Cluster']):
    label = f'Neighborhood: {name} Cluster: {clu}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=colors[clu+1],
        fill=True,
        fill_color=colors[clu+1],
        fill_opacity=0.7,
        parse_html=False).add_to(cluster_map)  

folium.Marker(
    [49.220011, -123.064135],
    popup='Victoria-Fraserview',
    icon=folium.Icon(color='blue', icon='thumbs-up')).add_to(cluster_map) 

cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References
