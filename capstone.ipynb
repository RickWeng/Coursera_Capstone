# %% [markdown]
# # Capstone

# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Introduction

# %% [markdown]
# Business problem: Which neighborhood in the City of Vancouver should the investor open a chinese restaurant? Chinese account for nearly 27% of the population. Chinese restaurants have been emerging over the past decade. An accelerating rise of chinese-oriented restaurants can be expected. These cultural analysts foresee an accelerating rise of Asian-oriented restaurants, retail outlets, artistic events, religions, community service organizations, schools, neighbourhood enclaves, family-reunification programs, signage, international business partnerships, corporate customs and Asian-language newspapers and TV stations. Forty-three per cent of Metro Vancouver residents have an Asian heritage, which is a much higher proportion than any other major city outside the continent of Asia. Based on Statistics Canada reports, the number of those with Asian roots in Metro Vancouver will continue to grow at a faster rate than the non-Asian population. Around the globe, the only major cities outside Asia {* with more than 1.2 million residents} that come close to Metro Vancouver for their portion of residents with Asian backgrounds are San Francisco (33 per cent Asian), London, England (21 per cent), Metro Toronto (35 per cent), Calgary (23 per cent) and Sydney, Australia (19 per cent).

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Data

# %% [markdown]
# Postal code
# Geocoding
# shapefile to geojson centroid
#
# Census data
# Calculate population density
# Mother tongue for the total population excluding institutional residents - 100% data
# Language spoken most often at home for the total population excluding institutional residents - 100% data
# Selected places of birth for the immigrant population in private households - 25% sample data
#
# Foursquare API
# Location of venues
# heatmap

# %%
import requests
import urllib
from zipfile import ZipFile

# %%
# get vancouver boundary shapefile
url = 'ftp://webftp.vancouver.ca/OpenData/shape/local_area_boundary_shp.zip'
response = urllib.request.urlretrieve(url, 'boundary.zip')
with ZipFile('boundary.zip', 'r') as boundary: 
    # print all the contents of the zip file 
    boundary.printdir() 
    
    # extract all files 
    boundary.extractall() 
    print('All files were extracted.')
# Out:
# File Name                                             Modified             Size
# local_area_boundary.dbf                        2019-02-03 02:19:00         6148
# local_area_boundary.prj                        2019-02-03 02:19:00          413
# local_area_boundary.shp                        2019-02-03 02:19:00        20772
# local_area_boundary.shx                        2019-02-03 02:19:00          276
# All files were extracted.

# %%
#import shapefile
#from json import dumps

# %%
# read the shapefile
#reader = shapefile.Reader('local_area_boundary.shp')
#fields = reader.fields[1:]
#field_names = [field[0] for field in fields]
#buffer = []
#for sr in reader.shapeRecords():
    #atr = dict(zip(field_names, sr.record))
    #geom = sr.shape.__geo_interface__
    #buffer.append(dict(type="Feature", \
                       #geometry=geom, properties=atr)) 

# write the GeoJSON file
#geojson = open('boundary.json', 'w')
#geojson.write(dumps({'type': 'FeatureCollection', 'features': buffer}, indent=2) + '\n')
#geojson.close()

# %%
import geopandas
import pyepsg

# %%
shp = geopandas.GeoDataFrame.from_file('local_area_boundary.shp')
# check current coordinate system
pyepsg.get(shp.crs['init'].split(':')[1])
# Out:
# <ProjectedCRS: 26910, NAD83 / UTM zone 10N>

# %%
# make coordinate system consistent
new_shp = shp.to_crs(epsg='4326')
# transfer shp to json
van_json = new_shp.to_json()
van_json
# Out:

#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.12180104784004, 49.245555693157456]},
#   'bbox': [-123.12180104784004,
#    49.245555693157456,
#    -123.12180104784004,
#    49.245555693157456]},
#  {'id': '14',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.13543740310479, 49.28501116202803]},
#   'bbox': [-123.13543740310479,
#    49.28501116202803,
#    -123.13543740310479,
#    49.28501116202803]},
#  {'id': '15',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.03764720211959, 49.21702062437662]},
#   'bbox': [-123.03764720211959,
#    49.21702062437662,
#    -123.03764720211959,
#    49.21702062437662]},
#  {'id': '16',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.04016670661927, 49.247341725772266]},
#   'bbox': [-123.04016670661927,
#    49.247341725772266,
#    -123.04016670661927,
#    49.247341725772266]},
#  {'id': '17',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.04026999509304, 49.277932902087]},
#   'bbox': [-123.04026999509304,
#    49.277932902087,
#    -123.04026999509304,
#    49.277932902087]},
#  {'id': '18',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.06413496140198, 49.22001104473882]},
#   'bbox': [-123.06413496140198,
#    49.22001104473882,
#    -123.06413496140198,
#    49.22001104473882]},
#  {'id': '19',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.07288517222939, 49.24668568425557]},
#   'bbox': [-123.07288517222939,
#    49.24668568425557,
#    -123.07288517222939,
#    49.24668568425557]},
#  {'id': '20',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.08823526080843, 49.27821889760215]},
#   'bbox': [-123.08823526080843,
#    49.27821889760215,
#    -123.08823526080843,
#    49.27821889760215]},
#  {'id': '21',
#   'type': 'Feature',
#   'properties': {},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.06672835106983, 49.27643859705032]},
#   'bbox': [-123.06672835106983,
#    49.27643859705032,
#    -123.06672835106983,
#    49.27643859705032]}]

# %%
column_names = ['Latitude', 'Longitude'] 

# instantiate the dataframe
van = pd.DataFrame(columns=column_names)

# %%
# get latitude and longitude of each centroid
for data in van_data:
    van_latlon = data['geometry']['coordinates']
    van_lat = van_latlon[1]
    van_lon = van_latlon[0]
    van = van.append({'Latitude': van_lat,'Longitude': van_lon}, ignore_index=True)

# %%
van
# Out:
#      Latitude   Longitude
# 0   49.218755 -123.092038
# 1   49.263065 -123.098513
# 2   49.244766 -123.103147
# 3   49.280747 -123.116567
# 4   49.267540 -123.163295
# 5   49.237960 -123.189548
# 6   49.223655 -123.159576
# 7   49.246804 -123.161669
# 8   49.268401 -123.203467
# 9   49.210208 -123.128382
# 10  49.226404 -123.123024
# 11  49.245680 -123.139760
# 12  49.264541 -123.131049
# 13  49.245556 -123.121801
# 14  49.285011 -123.135437
# 15  49.217021 -123.037647
# 16  49.247342 -123.040167
# 17  49.277933 -123.040270
# 18  49.220011 -123.064135
# 19  49.246686 -123.072885
# 20  49.278219 -123.088235
# 21  49.276439 -123.066728

# %%
shp['NAME']
# Out:
# 0                       Sunset
# 1               Mount Pleasant
# 2                   Riley Park
# 3                     Downtown
# 4                    Kitsilano
# 5            Dunbar-Southlands
# 6                   Kerrisdale
# 7                Arbutus-Ridge
# 8              West Point Grey
# 9                      Marpole
# 10                    Oakridge
# 11                 Shaughnessy
# 12                    Fairview
# 13                South Cambie
# 14                    West End
# 15                   Killarney
# 16         Renfrew-Collingwood
# 17            Hastings-Sunrise
# 18         Victoria-Fraserview
# 19    Kensington-Cedar Cottage
# 20                  Strathcona
# 21          Grandview-Woodland
# Name: NAME, dtype: object

# %%
shp['area'] = shp.area/10**6

# %%
dict = {'Neighborhood':shp['NAME'], 
                'Latitude':van['Latitude'], 
                'Longitude':van['Longitude'], 
                'Area':shp['area']}

# instantiate the dataframe
neighborhood = pd.DataFrame(dict)

# %%
neighborhood
# Out:
#                 Neighborhood   Latitude   Longitude      Area
# 0                     Sunset  49.218755 -123.092038  6.575731
# 1             Mount Pleasant  49.263065 -123.098513  3.720549
# 2                 Riley Park  49.244766 -123.103147  4.931676
# 3                   Downtown  49.280747 -123.116567  4.674227
# 4                  Kitsilano  49.267540 -123.163295  6.362855
# 5          Dunbar-Southlands  49.237960 -123.189548  9.079848
# 6                 Kerrisdale  49.223655 -123.159576  6.608907
# 7              Arbutus-Ridge  49.246804 -123.161669  3.700620
# 8            West Point Grey  49.268401 -123.203467  5.300219
# 9                    Marpole  49.210208 -123.128382  6.003074
# 10                  Oakridge  49.226404 -123.123024  4.023603
# 11               Shaughnessy  49.245680 -123.139760  4.480286
# 12                  Fairview  49.264541 -123.131049  3.635361
# 13              South Cambie  49.245556 -123.121801  2.176353
# 14                  West End  49.285011 -123.135437  2.256228
# 15                 Killarney  49.217021 -123.037647  6.933989
# 16       Renfrew-Collingwood  49.247342 -123.040167  8.100377
# 17          Hastings-Sunrise  49.277933 -123.040270  8.332271
# 18       Victoria-Fraserview  49.220011 -123.064135  5.500531
# 19  Kensington-Cedar Cottage  49.246686 -123.072885  7.252499
# 20                Strathcona  49.278219 -123.088235  4.369801
# 21        Grandview-Woodland  49.276439 -123.066728  4.754135

# %%
census_df
# Out:
#                 Neighborhood Chinese
# 0              Arbutus-Ridge    6970
# 1                   Downtown    9490
# 2          Dunbar-Southlands    6525
# 3                   Fairview    3865
# 4         Grandview-Woodland    3885
# 5           Hastings-Sunrise   13120
# 6   Kensington-Cedar Cottage   15560
# 7                 Kerrisdale    6445
# 8                  Killarney   11670
# 9                  Kitsilano    3615
# 10                   Marpole   10585
# 11            Mount Pleasant    3580
# 12                  Oakridge    7505
# 13       Renfrew-Collingwood   21370
# 14                Riley Park    5210
# 15               Shaughnessy    3340
# 16              South Cambie    1995
# 17                Strathcona    2865
# 18                    Sunset    8180
# 19       Victoria-Fraserview   15710
# 20                  West End    2740
# 21           West Point Grey    3100

# %%
cleaned_neighborhood = pd.merge(neighborhood, census_df, on='Neighborhood')
cleaned_neighborhood
# Out:
#                 Neighborhood   Latitude   Longitude      Area Chinese
# 0                     Sunset  49.218755 -123.092038  6.575731    8180
# 1             Mount Pleasant  49.263065 -123.098513  3.720549    3580
# 2                 Riley Park  49.244766 -123.103147  4.931676    5210
# 3                   Downtown  49.280747 -123.116567  4.674227    9490
# 4                  Kitsilano  49.267540 -123.163295  6.362855    3615
# 5          Dunbar-Southlands  49.237960 -123.189548  9.079848    6525
# 6                 Kerrisdale  49.223655 -123.159576  6.608907    6445
# 19  2145.467366
# 20   655.636295
# 21   817.183377

# %%
# Out:
# 0     1243.968169
# 1      962.223642
# 2     1056.435881
# 3     2030.282296
# 4      568.141185
# 5      718.624330
# 6      975.199019
# 7     1883.467974
# 8      584.881449
# 9     1763.263213
# 10    1865.243560
# 11     745.488135
# 12    1063.168279
# 13     916.670950
# 14    1214.416348
# 15    1683.014003
# 16    2638.148844
# 17    1574.600765
# 18    2856.088062
# 19    2145.467366
# 20     655.636295
# 21     817.183377
# dtype: float64

# %%
import pandas as pd

# %%
url_census = 'ftp://webftp.vancouver.ca/opendata/xls/CensusLocalAreaProfiles2016.csv'

# %%
census = urllib.request.urlretrieve(url, 'CensusLocalAreaProfiles2016.csv')

# %%
census = pd.read_csv('CensusLocalAreaProfiles2016.csv',encoding = "ISO-8859-1") 
# Preview the first 5 lines of the loaded data 
census.head()
# Out:
#   The data shown here is provided by Statistics Canada from the 2016 Census as a custom data order for the City of Vancouver using the City's 22 local planning areas  \
# 0  The data may be reproduced provided they are c...
# 1                                                NaN
# 2   CENSUS DATA FOR CITY OF VANCOUVER LOCAL AREAS...
# 3                                                 ID
# 4                                                  1
#
#                                           Unnamed: 1      Unnamed: 2  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                           Variable  Arbutus-Ridge
# 4   Total - Age groups and average age of the pop...          15,295
#
#   Unnamed: 3          Unnamed: 4 Unnamed: 5           Unnamed: 6  \
# 0        NaN                 NaN        NaN                  NaN
# 1        NaN                 NaN        NaN                  NaN
# 2        NaN                 NaN        NaN                  NaN
# 3  Downtown   Dunbar-Southlands   Fairview   Grandview-Woodland
# 4     62,030              21,425     33,620               29,175
#
#           Unnamed: 7                 Unnamed: 8   Unnamed: 9       ...        \
# 0                NaN                        NaN          NaN       ...
# 1                NaN                        NaN          NaN       ...
# 2                NaN                        NaN          NaN       ...
# 3  Hastings-Sunrise   Kensington-Cedar Cottage   Kerrisdale        ...
# 4             34,575                     49,325       13,975       ...
#
#    Unnamed: 16   Unnamed: 17    Unnamed: 18  Unnamed: 19 Unnamed: 20  \
# 0          NaN           NaN            NaN          NaN         NaN
# 1          NaN           NaN            NaN          NaN         NaN
# 2          NaN           NaN            NaN          NaN         NaN
# 3  Riley Park   Shaughnessy   South Cambie   Strathcona      Sunset
# 4       22,555         8,430          7,970       12,585      36,500
#
#            Unnamed: 21 Unnamed: 22       Unnamed: 23     Unnamed: 24  \
# 0                  NaN         NaN               NaN             NaN
# 1                  NaN         NaN               NaN             NaN
# 2                  NaN         NaN               NaN             NaN
# 3  Victoria-Fraserview   West End   West Point Grey   Vancouver CSD
# 4               31,065      47,200            13,065         631,485
#
#       Unnamed: 25
# 0             NaN
# 1             NaN
# 2             NaN
# 3  Vancouver CMA
# 4       2,463,430
#
# [5 rows x 26 columns]

# %%
census.columns = census.iloc[3, :].str.rstrip()

# %%
census.drop(['ID'], axis=1, inplace=True)
census.drop(['Vancouver CSD', 'Vancouver CMA'], axis=1, inplace=True)
census.drop(census.index[0:4], axis=0, inplace=True)

# %%
del census.columns.name
census.reset_index(drop=True, inplace=True)

# %%
census
# Out:
#                                                Variable Arbutus-Ridge  \
# 0      Total - Age groups and average age of the pop...        15,295
# 1                                         0 to 14 years          2015
# 2                                          0 to 4 years           455
# 3                                          5 to 9 years           685
# 4                                        10 to 14 years           880
# 5                                        15 to 64 years          9805
# 6                                        15 to 19 years          1230
# 7                                        20 to 24 years          1165
# 8                                        25 to 29 years           805
# 9                                        30 to 34 years           570
# 10                                       35 to 39 years           560
# 11                                       40 to 44 years           965
# 12                                       45 to 49 years          1350
# 13                                       50 to 54 years          1310
# 14                                       55 to 59 years           920
# 15                                       60 to 64 years           935
# 16                                    65 years and over          3480
# 17                                       65 to 69 years           915
# 18                                       70 to 74 years           635
# 19                                       75 to 79 years           590
# 20                                       80 to 84 years           525
# 21                                    85 years and over           810
# 22                                       85 to 89 years           430
# 23                                       90 to 94 years           270
# 24                                       95 to 99 years            90
# 25                                   100 years and over            20
# 26      Total - Age groups and average age of males ...          6925
# 27                                        0 to 14 years          1055
# 28                                         0 to 4 years           230
# 29                                         5 to 9 years           345
# ...                                                 ...           ...
# 5559                                             French            45
# 5560                              Non-official language           665
# 5561                                         Aboriginal             0
# 5562                                     Non-Aboriginal           665
# 5563                                 English and French             0
# 5564                  English and non-official language            25
# 5565                   French and non-official language            10
# 5566          English, French and non-official language             0
# 5567    Total - Other language(s) used regularly at ...          3720
# 5568                                               None          3250
# 5569                                            English           140
# 5570                                             French            10
# 5571                              Non-official language           305
# 5572                                         Aboriginal             0
# 5573                                     Non-Aboriginal           305
# 5574                                 English and French             0
# 5575                  English and non-official language            15
# 5576                   French and non-official language             0
# 5577          English, French and non-official language             0
# 5578    Total - Other language(s) used regularly at ...          3665
# 5579                                               None          3120
# 5580                                            English           135
# 5581                                             French            40
# 5582                              Non-official language           355
# 5583                                         Aboriginal             0
# 5584                                     Non-Aboriginal           360
# 5585                                 English and French             0
# 5586                  English and non-official language            10
# 5587                   French and non-official language             0
# 5588          English, French and non-official language             0
#
#      Downtown Dunbar-Southlands Fairview Grandview-Woodland Hastings-Sunrise  \
# 0      62,030            21,425   33,620             29,175           34,575
# 1        4000              3545     2580               3210             4595
# 2        2080               675     1240               1320             1510
# 3        1105              1225      760               1025             1560
# 4         810              1650      580                865             1525
# 5       51275             14215    25140              22535            23945
# 6        1180              1800      655                830             1780
# 7        4050              1740     1865               1525             2360
# 8        8810              1110     4025               3450             2755
# 9        9750               695     4395               3720             2515
# 10       6620               765     3175               2835             2265
# 11       4755              1325     2450               2425             2300
# 12       4610              2025     2340               2220             2615
# 13       4160              1895     2110               2025             2800
# 14       3970              1460     2145               1885             2490
# 15       3365              1400     1980               1615             2055
# 16       6760              3660     5895               3435             6040
# 17       2640              1290     2005               1330             1775
# 18       1710               865     1345                750             1065
# 19       1095               655      930                520             1125
# 20        700               415      690                425             1085
# 21        615               430      930                415              990
# 22        390               265      525                290              655
# 23        170               115      270                100              265
# 24         45                45      105                 25               60
# 25         10                10       25                  5               10
# 26      33100             10340    15115              14255            16910
# 27       2080              1830     1335               1680             2360
# 28       1085               350      640                680              795
# 29        575               645      405                530              780
# ...       ...               ...      ...                ...              ...
# 5559      505               210      455                320              145
# 5560     2535               680      910                640             1335
# 5561        0                10        0                 15                0
# 5562     2540               675      910                620             1335
# 5563       10                 0        0                  0                0
# 5564       15                10        0                  0               35
# 5565       70                15       30                 20               10
# 5566        0                 0        0                  0                0
# 5567    22905              5935    11260              10010            10275
# 5568    21065              5375    10560               9450             9370
# 5569      290                95       75                 90              220
# 5570      250               105      205                140               70
# 5571     1235               345      405                320              585
# 5572        0                10        0                  0                0
# 5573     1240               335      410                315              585
# 5574       10                 0        0                  0                0
# 5575        0                15        0                 10               20
# 5576       55                10       10                  0               10
# 5577        0                 0       10                  0                0
# 5578    19235              5590    12780              10190             9875
# 5579    17290              5035    11900               9525             8805
# 5580      360               100       95                150              230
# 5581      255               105      255                180               65
# 5582     1300               335      500                320              750
# 5583        0                10        0                 15                0
# 5584     1300               335      505                305              750
# 5585        0                 0        0                  0                0
# 5586       10                 0        0                  0               15
# 5587       15                10       20                 10                0
# 5588        0                 0        0                  0                0
#
#      Kensington-Cedar Cottage Kerrisdale Killarney       ...       Oakridge  \
# 0                      49,325     13,975    29,325       ...         13,030
# 1                        7060       1880      4185       ...           1565
# 2                        2515        430      1300       ...            490
# 3                        2390        600      1400       ...            480
# 4                        2160        845      1485       ...            590
# 5                       35385       9395     19985       ...           8560
# 6                        2630       1050      1760       ...            835
# 7                        3470       1150      1995       ...           1040
# 8                        4325        905      1755       ...            995
# 9                        4205        560      1800       ...            735
# 10                       3805        545      1810       ...            645
# 11                       3700        770      2040       ...            685
# 12                       3640       1245      2165       ...            920
# 13                       3570       1245      2395       ...           1010
# 14                       3190       1045      2290       ...            825
# 15                       2840        885      1975       ...            855
# 16                       6875       2700      5150       ...           2910
# 17                       2190        850      1745       ...            855
# 18                       1385        675      1045       ...            540
# 19                       1280        495       890       ...            500
# 20                       1035        360       710       ...            440
# 21                        985        320       765       ...            580
# 22                        640        195       475       ...            310
# 23                        260        100       195       ...            220
# 24                         65         20        80       ...             45
# 25                         15          0        10       ...              5
# 26                      24060       6495     13935       ...           5995
# 27                       3665        970      2195       ...            815
# 28                       1330        245       685       ...            250
# 29                       1240        285       745       ...            250
# ...                       ...        ...       ...       ...            ...
# 5559                      300         40        70       ...             25
# 5560                     2085        700      1480       ...            930
# 5561                        0          0        10       ...              0
# 5562                     2085        700      1475       ...            935
# 5563                        0          0         0       ...              0
# 5564                       35          0        45       ...             20
# 5565                       30         15        20       ...             15
# 5566                        0          0         0       ...              0
# 5567                    15410       3660      8305       ...           3225
# 5568                    13885       3190      7245       ...           2610
# 5569                      390         90       290       ...            170
# 5570                      150         15        20       ...             15
# 5571                      960        340       720       ...            405
# 5572                        0          0        10       ...              0
# 5573                      960        340       715       ...            405
# 5574                        0          0         0       ...             10
# 5575                       15          0        25       ...             15
# 5576                       10         10        15       ...              0
# 5577                        0          0         0       ...              0
# 5578                    15205       3375      8425       ...           3115
# 5579                    13525       2900      7265       ...           2410
# 5580                      360         75       315       ...            150
# 5581                      150         25        50       ...             10
# 5582                     1125        360       760       ...            525
# 5583                        0          0         0       ...              0
# 5584                     1125        360       760       ...            525
# 5585                        0          0         0       ...              0
# 5586                       20         10        20       ...              0
# 5587                       20          0        10       ...             10
# 5588                        0          0         0       ...              0
#
#      Renfrew-Collingwood Riley Park Shaughnessy South Cambie Strathcona  \
# 0                 51,530     22,555       8,430        7,970     12,585
# 1                   6305       3415        1175         1105       1065
# 2                   2065       1175         270          360        360
# 3                   2115       1160         405          365        365
# 4                   2130       1080         500          375        340
# 5                  37315      15875        5440         5430       8745
# 6                   2815       1065         575          380        370
# 7                   4340       1335         635          475        575
# 8                   4820       1955         545          705        885
# 9                   3985       2010         445          670        960
# 10                  3490       1745         380          635        960
# 11                  3350       1680         385          530        830
# 12                  3570       1710         685          620        985
# 13                  4115       1700         665          530       1080
# 14                  3685       1425         570          460       1150
# 15                  3145       1240         565          425        945
# 16                  7910       3260        1820         1435       2775
# 17                  2545       1115         555          375        830
# 18                  1570        610         370          255        485
# 19                  1495        565         275          210        495
# 20                  1215        485         240          235        445
# 21                  1085        490         385          360        520
# 22                   700        305         185          170        310
# 23                   300        135         130          145        140
# 24                    70         40          60           40         60
# 25                    15         10          10           10         10
# 26                 25140      10775        3930         3785       6835
# 27                  3270       1780         585          580        525
# 28                  1075        625         145          185        185
# 29                  1080        585         195          195        175
# ...                  ...        ...         ...          ...        ...
# 5559                 145        185          35           70         70
# 5560                3040        690         280          265        215
# 5561                  10          0           0            0         10
# 5562                3040        690         285          265        205
# 5563                   0          0           0            0          0
# 5564                  45         10           0            0          0
# 5565                  40         25          20           10          0
# 5566                   0          0           0            0          0
# 5567               15865       6930        2235         2350       2530
# 5568               13715       6415        2000         2145       2365
# 5569                 570         80          50           35         55
# 5570                  70         80          15           25         35
# 5571                1480        335         160          150         80
# 5572                   0          0           0            0          0
# 5573                1475        335         160          150         80
# 5574                   0          0           0            0          0
# 5575                  15         10           0            0          0
# 5576                  20         15           0            0          0
# 5577                   0          0           0            0          0
# 5578               15160       7190        2065         2425       2275
# 5579               12920       6575        1830         2190       2060
# 5580                 560        145          85           65         45
# 5581                  75        110          20           45         40
# 5582                1565        350         120          115        130
# 5583                   0          0           0            0          0
# 5584                1565        350         120          115        125
# 5585                   0          0           0            0          0
# 5586                  30          0           0            0          0
# 5587                  20         10          15           10          0
# 5588                   0          0           0            0          0
#
#       Sunset Victoria-Fraserview West End West Point Grey
# 0     36,500              31,065   47,200          13,065
# 1       5460                3790     1945            1900
# 2       1695                1175      965             420
# 3       1780                1210      560             670
# 4       1985                1410      415             810
# 5      25490               21090    38255            8660
# 6       2570                1895      610             915
# 7       2975                2220     3100            1215
# 8       2900                2295     7375             780
# 9       2450                1985     7140             610
# 10      2535                1795     4750             575
# 11      2540                1805     3280             755
# 12      2660                2080     3145            1055
# 13      2610                2450     3230            1030
# 14      2320                2375     2945             865
# 15      1925                2205     2680             860
# 16      5550                6185     7000            2510
# 17      1735                1885     2485             900
# 18      1195                1110     1815             605
# 19      1010                1120     1155             415
# 20       865                 935      750             275
# 21       745                1135      800             310
# 22       480                 670      490             195
# 23       200                 340      240              80
# 24        50                  95       55              25
# 25        10                  25       10               5
# 26     17900               14855    24670            6215
# 27      2875                1995      980             980
# 28       885                 600      480             245
# 29       915                 640      280             335
# ...      ...                 ...      ...             ...
# 5559      90                  45      800              90
# 5560    1835                1845     1820             385
# 5561       0                   0       10               0
# 5562    1835                1845     1815             385
# 5563       0                   0        0               0
# 5564      20                  45       10              10
# 5565      10                  30       50              30
# 5566       0                   0        0               0
# 5567   10935                8910    19065            3675
# 5568    9630                7580    17465            3385
# 5569     275                 380      305              65
# 5570      40                  15      360              40
# 5571     980                 895      900             170
# 5572       0                   0        0               0
# 5573     975                 895      895             175
# 5574       0                   0        0               0
# 5575      10                  20        0               0
# 5576      10                  15       35              15
# 5577       0                   0        0               0
# 5578   10415                8390    16150            3585
# 5579    9295                7040    14495            3250
# 5580     205                 335      270              55
# 5581      50                  30      445              50
# 5582     850                 945      925             215
# 5583       0                   0        0               0
# 5584     850                 945      915             215
# 5585       0                   0        0               0
# 5586      10                  30        0               0
# 5587       0                  15       20              10
# 5588       0                   0        0               0
#
# [5589 rows x 23 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-525-09583ff58213> in <module>
# ----> 1 pd.wide_to_long(census)
#
# TypeError: wide_to_long() missing 3 required positional arguments: 'stubnames', 'i', and 'j'

# %%
tcensus = census.transpose()
tcensus.columns = tcensus.iloc[0,:].str.lstrip()

# %%
cleaned_census = tcensus['Chinese'].iloc[1:,0]

# %%
cleaned_census
# Out:
# Arbutus-Ridge                6970
# Downtown                     9490
# Dunbar-Southlands            6525
# Fairview                     3865
# Grandview-Woodland           3885
# Hastings-Sunrise            13120
# Kensington-Cedar Cottage    15560
# Kerrisdale                   6445
# Killarney                   11670
# Kitsilano                    3615
# Marpole                     10585
# Mount Pleasant               3580
# Oakridge                     7505
# Renfrew-Collingwood         21370
# Riley Park                   5210
# Shaughnessy                  3340
# South Cambie                 1995
# Strathcona                   2865
# Sunset                       8180
# Victoria-Fraserview         15710
# West End                     2740
# West Point Grey              3100
# Name: Chinese, dtype: object

# %%
census_df = cleaned_census.to_frame().reset_index()
census_df.rename(columns={'index':'Neighborhood'}, inplace=True)

# %%
census_df
# Out:
#                 Neighborhood Chinese
# 0              Arbutus-Ridge    6970
# 1                   Downtown    9490
# 2          Dunbar-Southlands    6525
# 3                   Fairview    3865
# 4         Grandview-Woodland    3885
# 5           Hastings-Sunrise   13120
# 6   Kensington-Cedar Cottage   15560
# 7                 Kerrisdale    6445
# 8                  Killarney   11670
# 9                  Kitsilano    3615
# 10                   Marpole   10585
# 11            Mount Pleasant    3580
# 12                  Oakridge    7505
# 13       Renfrew-Collingwood   21370
# 14                Riley Park    5210
# 15               Shaughnessy    3340
# 16              South Cambie    1995
# 17                Strathcona    2865
# 18                    Sunset    8180
# 19       Victoria-Fraserview   15710
# 20                  West End    2740
# 21           West Point Grey    3100

# %%
from geopy.geocoders import Nominatim
import folium

# %%
# geocoding vancouver
address = 'Vancouver, British Columbia'
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Vancouver are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Vancouver are 49.2608724, -123.1139529.

# %%
import folium

mapa = folium.Map([latitude, longitude],
                  zoom_start=12,
                  tiles='cartodbpositron')

mapa.choropleth(geo_data=gjson,fill_color='grey')
for lat, lng in zip(van['Latitude'], van['Longitude']):
    label = f'lat: {lat}\nlng: {lng}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='#f9ba00',
        fill=True,
        fill_color='#f9ba00',
        fill_opacity=0.7,
        parse_html=False).add_to(mapa)  

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# <ProjectedCRS: 26910, NAD83 / UTM zone 10N>

# %%
cpoint
# Out:
# 0      POINT (493297.623885159 5451778.302478819)
# 1     POINT (492832.5710942394 5456704.857862097)
# 2     POINT (492492.6143612485 5454670.966576269)
# 3     POINT (491522.0198607397 5458672.354567361)
# 4     POINT (488120.2612360372 5457210.450702526)
# 5     POINT (486202.1625533467 5453926.527669333)
# 6     POINT (488380.5557101681 5452331.198394036)
# 7     POINT (488233.6652576678 5454905.018354704)
# 8     POINT (485198.0568214911 5457313.287573236)
# 9     POINT (490649.4184549566 5450831.948140365)
# 10    POINT (491042.5354563056 5452631.796960058)
# 11    POINT (489827.9557256088 5454776.881854942)
# 12    POINT (490465.6383772573 5456872.433940169)
# 13    POINT (491135.0425028555 5454760.763597974)
# 14    POINT (490150.4143491607 5459148.729315017)
# 15    POINT (497258.3720622362 5451582.071860868)
# 16    POINT (497076.6808230506 5454952.955290285)
# 17    POINT (497070.9746404239 5458353.790556923)
# 18    POINT (495329.7036570702 5451915.812631234)
# 19    POINT (494695.3719458144 5454881.802774654)
# 20    POINT (493582.2736101437 5458388.549952868)
# 21    POINT (495146.3879604022 5458189.029613946)
# dtype: object

# %%
cjson
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123.0920382187122, 49.21875524075676]}, "bbox": [-123.0920382187122, 49.21875524075676, -123.0920382187122, 49.21875524075676]}, {"id": "1", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123.09851250389197, 49.26306545462446]}, "bbox": [-123.09851250389197, 49.26306545462446, -123.09851250389197, 49.26306545462446]}, {"id": "2", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123.10314689371549, 49.24476610864839]}, "bbox": [-123.10314689371549, 49.24476610864839, -123.10314689371549, 49.24476610864839]}, {"id": "3", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123.1165669909403, 49.28074666385142]}, "bbox": [-123.1165669909403, 49.28074666385142, -123.1165669909403, 49.28074666385142]}, {"id": "4", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123.1632954860576, 49.267539969266124]}, "bbox": [-123.1632954860576, 49.267539969266124, -123.1632954860576, 49.267539969266124]}, {"id": "5", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123.1895478459803, 49.237960248459856]}, "bbox": [-123.1895478459803, 49.237960248459856, -123.1895478459803, 49.237960248459856]}, {"id": "6", "type": "Feature", "properties": {}, "geometry": {"type": "Point", "coordinates": [-123
# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-486-72d7eef5e22a> in <module>
# ----> 1 cjson.area
#
# AttributeError: 'str' object has no attribute 'area'

# %%
hidro.crs
# Out:
# {'init': 'epsg:26910'}

# %%
hidro
# Out:
#    MAPID                      NAME  \
# 0    SUN                    Sunset
# 1     MP            Mount Pleasant
# 2     RP                Riley Park
# 3    CBD                  Downtown
# 4   KITS                 Kitsilano
# 5     DS         Dunbar-Southlands
# 6   KERR                Kerrisdale
# 7     AR             Arbutus-Ridge
# 8    WPG           West Point Grey
# 9   MARP                   Marpole
# 10   OAK                  Oakridge
# 11  SHAU               Shaughnessy
# 12  FAIR                  Fairview
# 13    SC              South Cambie
# 14    WE                  West End
# 15   KIL                 Killarney
# 16    RC       Renfrew-Collingwood
# 17    HS          Hastings-Sunrise
# 18    VF       Victoria-Fraserview
# 19    KC  Kensington-Cedar Cottage
# 20   STR                Strathcona
# 21    GW        Grandview-Woodland
#
#                                              geometry      area
# 0   POLYGON ((492208.4021460207 5450157.053499949,...  6.575731
# 1   POLYGON ((492676.5070098151 5457379.340971759,...  3.720549
# 2   POLYGON ((492310.7074588875 5453376.090940117,...  4.931676
# 3   POLYGON ((491836.3489202514 5459718.918809408,...  4.674227
# 4   POLYGON ((489985.3567529821 5458071.445235047,...  6.362855
# 5   POLYGON ((487615.5153227601 5455027.114970088,...  9.079848
# 6   POLYGON ((486957.9095499917 5451434.123423224,...  6.608907
# 7   POLYGON ((488896.3689033413 5456062.110754157,...  3.700620
# 8   POLYGON ((483675.094250936 5458487.318162165, ...  5.300219
# 9   POLYGON ((492208.4021460207 5450157.053499949,...  6.003074
# 10  POLYGON ((492310.7074588875 5453376.090940117,...  4.023603
# 11  POLYGON ((488696.3290805931 5453538.809001902,...  4.480286
# 12  POLYGON ((489377.1098311909 5456049.71147632, ...  3.635361
# 13  POLYGON ((491556.708018563 5453913.232452564, ...  2.176353
# 14  POLYGON ((489985.3567529821 5458071.445235047,...  2.256228
# 15  POLYGON ((498283.7087678414 5449705.685955254,...  6.933989
# 16  POLYGON ((498284.9079333543 5453557.160931887,...  8.100377
# 17  POLYGON ((495892.6527547317 5460083.767578724,...  8.332271
# 18  POLYGON ((495860.2306125091 5450157.766683207,...  5.500531
# 19  POLYGON ((495882.8193952732 5456581.277541871,...  7.252499
# 20  POLYGON ((492779.9065237215 5459618.3627329, 4...  4.369801
# 21  POLYGON ((494399.4616452773 5459725.039320952,...  4.754135

# %%
# foursquare information
CLIENT_ID = 'CMGOG4ZRSMWXCBOJ5L1ERRLDS0KBNCDZB5YIQUBYV0RSFESM' # Foursquare ID
CLIENT_SECRET = 'WSNVRUT4NVSFXME5VVG3XQIIVFKJWLC5PVI5OFWNFCJ1NZ5Z' # Foursquare Secret
VERSION = '20190420' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
# create function to get nearby venues
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood',                   
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# get nearby venues
toronto_venues = getNearbyVenues(names=gc_zip['Neighborhood'],
                                   latitudes=gc_zip['Latitude'],
                                   longitudes=gc_zip['Longitude']
                                  )

# %%
print(toronto_venues.shape)
toronto_venues.head()

# %%
# count venues in each neighborhood 
toronto_venues.groupby('Neighborhood').count()

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

toronto_onehot.head()

# %%
# get the frequency of each venue category in each neighborhood
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped

# %% [markdown]
# ### Analysis

# %% [markdown]
# Calculate population density
# DBSCAN

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References
